# %%
import TensorFrost as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import imageio
import cv2 as cv
from IPython.display import Image
from IPython.display import Video
import os

tf.initialize(tf.opengl)

M = 1920
N = 1080 

boundary_thickness = 3

def Bilinear(tex, x, y):
    xi, yi = tf.floor(x), tf.floor(y)
    xf, yf = x-xi, y-yi
    xi, yi = tf.int(xi), tf.int(yi)
    oxf, oyf = 1.0-xf, 1.0-yf
    return tex[xi, yi]*oxf*oyf + tex[xi+1, yi]*xf*oyf + tex[xi, yi+1]*oxf*yf + tex[xi+1, yi+1]*xf*yf

def CubicHermit(x):
    x2 = x * x
    x3 = x2 * x
    return [-0.5 * x3 + x2 - 0.5 * x, 1.5 * x3 - 2.5 * x2 + 1.0, -1.5 * x3 + 2.0 * x2 + 0.5 * x, 0.5 * x3 - 0.5 * x2]

def CubicInterp(tex, x, y):
    N1, M1 = tex.shape

    xi, yi = tf.floor(x), tf.floor(y)
    xf, yf = x-xi, y-yi
    xi, yi = tf.int(xi), tf.int(yi)

    wx = CubicHermit(xf)
    wy = CubicHermit(yf)

    valueY = 0.0
    for j in range(-1, 3):
        valueX = 0.0
        for i in range(-1, 3):
            valueX = valueX + tex[xi + i, yi + j] * wx[i + 1]
        valueY = valueY + valueX * wy[j + 1]
        
    return valueY

def EulerAdvection(vx, vy, dt):
    i,j = vx.indices
    x, y = tf.float(i), tf.float(j)
    x1, y1 = x - vx*dt, y - vy*dt
    return x1, y1

def RK4Advection(vx, vy, dt):
    i, j = vx.indices
    x, y = tf.float(i), tf.float(j)

    x1, y1 = x - vx*dt/2.0, y - vy*dt/2.0
    vx1, vy1 = Bilinear(vx, x1, y1), Bilinear(vy, x1, y1)

    x2, y2 = x - vx1*dt/2.0, y - vy1*dt/2.0
    vx2, vy2 = Bilinear(vx, x2, y2), Bilinear(vy, x2, y2)

    x3, y3 = x - vx2*dt, y - vy2*dt
    vx3, vy3 = Bilinear(vx, x3, y3), Bilinear(vy, x3, y3)

    x4, y4 = x - (vx + 2.0*vx1 + 2.0*vx2 + vx3)*dt/6.0, y - (vy + 2.0*vy1 + 2.0*vy2 + vy3)*dt/6.0
    return x4, y4

def SemiLagrange(vx, vy, pressure, density, dt):
    x1, y1 = RK4Advection(vx, vy, dt)
    #x1, y1 = EulerAdvection(vx, vy, dt)

    vxb = Bilinear(vx, x1, y1)
    vyb = Bilinear(vy, x1, y1)
    densb = Bilinear(density, x1, y1)
    thr0 = 0.99
    thr1 = 1.01
    vx = tf.clamp(CubicInterp(vx, x1, y1), tf.min(vxb*thr0, vxb*thr1), tf.max(vxb*thr0, vxb*thr1))
    vy = tf.clamp(CubicInterp(vy, x1, y1), tf.min(vyb*thr0, vyb*thr1), tf.max(vyb*thr0, vyb*thr1))
    density = tf.clamp(CubicInterp(density, x1, y1), tf.min(densb*thr0, densb*thr1), tf.max(densb*thr0, densb*thr1))
    #pressure = CubicInterp(pressure, x1, y1)
    #vx = Bilinear(vx, x1, y1)
    #vy = Bilinear(vy, x1, y1)
    #pressure = Bilinear(pressure, x1, y1)
    #densitylin = Bilinear(density, x1, y1)
    #dens1 = densitylin*0.99
    #dens2 = densitylin*1.00
    #dens3 = tf.min(dens1, dens2)
    #dens4 = tf.max(dens1, dens2)
    #density = Bilinear(density, x1, y1)

    return [vx, vy, pressure, density]

def BFECC(vx, vy, pressure, density, dt):
    i, j = vx.indices
    x, y = tf.float(i), tf.float(j)
    
    # advect backwards
    x1, y1 = x - vx*dt, y - vy*dt
    vx1, vy1 = Bilinear(vx, x1, y1), Bilinear(vy, x1, y1)
    density1 = Bilinear(density, x1, y1)

    # advect forwards
    x2, y2 = x + vx*dt, y + vy*dt
    vx2, vy2 = Bilinear(vx1, x2, y2), Bilinear(vy1, x2, y2)
    density2 = Bilinear(density1, x2, y2)

    # compute backwards forwards error correction
    vx = vx + (vx - vx2)*0.5
    vy = vy + (vy - vy2)*0.5
    density = density + (density - density2)*0.5

    # advect corrected backwards
    vx3, vy3 = Bilinear(vx, x1, y1), Bilinear(vy, x1, y1)
    density3 = Bilinear(density, x1, y1)

    return [vx3, vy3, pressure, density3]

def Boundary(i, j):
    N1, M1 = i.shape
    return tf.select((i < boundary_thickness) | (i > N1-1-boundary_thickness) | (j < boundary_thickness) | (j > M1-1-boundary_thickness), 0.0, 1.0)

def LoadBC(f, i, j):
    return Boundary(i,j) * f[i, j]

def Jacobi(pressure, div, iterations):
    i, j = pressure.indices

    # pressure solve
    for it in range(iterations):
        pressure = (pressure[i-1, j] + pressure[i+1, j] + pressure[i, j-1] + pressure[i, j+1] - div) / 4.0

    return pressure

# red-black Gauss-Seidel
# def RBGS(pressure, div, iterations):
#     N1, M1 = pressure.shape
#     i0, j0 = tf.indices([N1, M1/2])

#     overrelax = 1.0

#     # pressure solve
#     for it in range(iterations):
#         new_pressure = tf.buffer([N1, M1], tf.float32)
#         # red
#         i, j = i0, 2*j0 + (i0 % 2)
#         new_pressure[i,j] = pressure[i, j] * (1.0 - overrelax) + overrelax * (pressure[i-1, j] + pressure[i+1, j] + pressure[i, j-1] + pressure[i, j+1] - div[i, j]) / 4.0

#         # black
#         i, j = i0, 2*j0 + ((i0+1) % 2)
#         new_pressure[i,j] = pressure[i, j] * (1.0 - overrelax) + overrelax * (new_pressure[i-1, j] + new_pressure[i+1, j] + new_pressure[i, j-1] + new_pressure[i, j+1] - div[i, j]) / 4.0
#         pressure = new_pressure

#     return pressure

def RBGS(pressure1, div, iterations, overrelax=1.0):
    tf.region_begin('RBGS')
    N1, M1 = pressure1.shape

    def sample(pressure, i, j):
        return tf.select((i >= 0) & (i < N1) & (j >= 0) & (j < M1), pressure[i, j], 0.0)

    def stencil(pressure, i, j):
        return (sample(pressure, i-1, j) + sample(pressure, i+1, j) + sample(pressure, i, j-1) + sample(pressure, i, j+1) - div[i, j]) / 4.0

    # pressure solve
    pressure2 = tf.buffer(pressure1.shape, tf.float32)
    i, j = pressure1.indices  
    #pressure1 = tf.copy(pressure)
    with tf.loop(iterations) as it:
        # red
        pressure2[i,j] = tf.select((i + j) % 2 == 0, tf.lerp(pressure1, stencil(pressure1, i, j), overrelax), pressure1)

        # black
        pressure1[i,j] = tf.select((i + j) % 2 == 1, tf.lerp(pressure2, stencil(pressure2, i, j), overrelax), pressure2)

    tf.region_end('RBGS')
    return pressure1

def Restrict(field):
    N1, M1 = field.shape
    N2, M2 = N1/2, M1/2
    i, j = tf.indices([N2, M2])
    i, j = 2*i, 2*j
    return 0.25*(field[i, j] + field[i+1, j] + field[i, j+1] + field[i+1, j+1])

def Prolong(field, orig):
    i, j = orig.indices
    return orig + Bilinear(field, tf.float(i)/2.0, tf.float(j)/2.0)

def Residual(pressure, div):
    i, j = pressure.indices
    return Boundary(i,j) * (div - (pressure[i-1, j] + pressure[i+1, j] + pressure[i, j-1] + pressure[i, j+1] - 4.0*pressure))

def VCycle(pressure, div):
    #pressure = RBGS(pressure, div, 1)
    res = Residual(pressure, div)
    res = Restrict(res)
    pressure0 = RBGS(tf.zeros(res.shape), 4.0*res, 4, 1.2)
    res1 = Residual(pressure0, 4.0*res)
    res1 = Restrict(res1)
    pressure1 = RBGS(tf.zeros(res1.shape), 4.0*res1, 12, 1.5)
    pressure0 = Prolong(pressure1, pressure0)
    pressure = Prolong(pressure0, pressure)
    pressure = RBGS(pressure, div, 1)
    return pressure

def PressureSolve(pressure, div):
    tf.region_begin('PressureSolve')
    pressure = VCycle(pressure, div)
    #pressure = VCycle(pressure, div)
    tf.region_end('PressureSolve')
    return pressure
    
def FluidTest():
    vx = tf.input([N, M], tf.float32)
    vy = tf.input([N, M], tf.float32)
    pressure = tf.input([N, M], tf.float32)
    density = tf.input([N, M], tf.float32)
    mouse = tf.input([5], tf.float32)
    params = tf.input([-1], tf.float32)

    canvas = tf.buffer([N, M, 3], tf.float32)

    dt = params[0]
    i,j = vx.indices
    x, y = tf.float(i), tf.float(j)

    vx, vy, pressure, density = SemiLagrange(vx, vy, pressure, density, dt)
    
    # add source
    source = tf.exp(-((y-mouse[0])**2.0 + (x-mouse[1])**2.0)/100.0)
    vx = vx + source*mouse[2]
    vy = vy + source*mouse[3]
    density = density + source*source * mouse[4]

    edge = Boundary(i, j)
    vel_decay = params[4]
    density_decay = params[5]
    vx = vx * vel_decay
    vy = vy * vel_decay
    density = tf.max(density * edge, 0.0) * density_decay

    # pressure solve
    # compute divergence
    div = (vx[i+1, j] - vx[i-1, j] + vy[i, j+1] - vy[i, j-1]) / 2.0
    curl = tf.abs(vy[i+1, j] - vy[i-1, j] - vx[i, j+1] + vx[i, j-1]) / 2.0

    pressure = PressureSolve(pressure*0.0, div)

    # subtract pressure gradient
    gradx = (pressure[i+1, j] - pressure[i-1, j])*1.0
    grady = (pressure[i, j+1] - pressure[i, j-1])*1.0
    vx = vx - gradx * edge
    vy = vy - grady * edge

    # vortex confinement

    # compute gradient of curl magnitude
    gradx = (curl[i+1, j] - curl[i-1, j])*1.0
    grady = (curl[i, j+1] - curl[i, j-1])*1.0

    # normalize gradient
    mag = tf.sqrt(gradx*gradx + grady*grady) + 1e-5
    gradx = edge*gradx / mag
    grady = edge*grady / mag

    # compute vortex force
    vortx = -grady * curl
    vorty = gradx * curl

    # add vortex force
    vort_scale = params[1]
    vx = vx + vortx * dt * vort_scale * edge
    vy = vy + vorty * dt * vort_scale * edge

    mag = params[2]*tf.sqrt(vx*vx + vy*vy) 
    mag = tf.clamp(mag, 0.0, 1.0)
    mag_d = params[3]*density
    mag_d = tf.clamp(mag_d, 0.0, 1.0)
    canvas[i, j, 0] = tf.smoothstep(0.0, 0.33, mag) + tf.smoothstep(0.66, 1.0, mag_d)
    canvas[i, j, 1] = tf.smoothstep(0.33, 0.66, mag) + tf.smoothstep(0.33, 0.66, mag_d)
    canvas[i, j, 2] = tf.smoothstep(0.66, 1.0, mag) + tf.smoothstep(0.0, 0.33, mag_d)
    #canvas[i, j, 0] = (0.277 + mag * (0.105 + mag * (-0.330 + mag * (-4.634 + mag * (6.228 + mag * (4.776 - 5.435 * mag))))))
    #canvas[i, j, 1] = (0.005 + mag * (1.404 + mag * (0.214 + mag * (-5.799 + mag * (14.179 + mag * (-13.745 + 4.645 * mag))))))
    #canvas[i, j, 2] = (0.334 + mag * (1.384 + mag * (0.095 + mag * (-19.332 + mag * (56.690 + mag * (-65.353 + 26.312 * mag))))))

    return [vx, vy, pressure, canvas, div, density, Residual(pressure, div)]

fluid = tf.compile(FluidTest)
# Out:
# TensorFrost module loaded!
# FluidTest:
#   Kernel count: 14
#   Intermediate buffers: 13
#   Host readbacks: 0
#   Host writes: 0
#   Lines of generated code: 583
#   IR Compile time: 182.238098 ms
#   Codegen time: 16.618000 ms
#   Host Compile time: 1454.625122 ms
#   Shader Compile time: 132.962402 ms

# %%
all_kernels = tf.get_all_generated_kernels()
print("Generated kernels:")
for k in all_kernels:
    print(k)
# Out:
# Generated kernels:
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1;\n  int N1;\n  int M1_2;\n  int v1_1;\n  int N1_2;\n  int N1_4;\n  int M1_4;\n  int v1_0;\n};\n\n', 'layout(std430, binding = 0) buffer buf_vy_2 {\n  uint vy_2_mem[];\n};\n\nfloat atomicAdd_vy_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vy_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_vx_2 {\n  uint vx_2_mem[];\n};\n\nfloat atomicAdd_vx_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vx_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_density_2 {\n  uint density_2_mem[];\n};\n\nfloat atomicAdd_density_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(density_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 3) buffer buf_vx {\n  uint vx_mem[];\n};\n\nfloat atomicAdd_vx(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vx_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 4) buffer buf_density {\n  uint density_mem[];\n};\n\nfloat atomicAdd_density(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(density_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 5) buffer buf_mouse {\n  uint mouse_mem[];\n};\n\nfloat atomicAdd_mouse(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(mouse_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 6) buffer buf_vy {\n  uint vy_mem[];\n};\n\nfloat atomicAdd_vy(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vy_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 7) buffer buf_params {\n  uint params_mem[];\n};\n\nfloat atomicAdd_params(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(params_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) br ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1;\n  int N1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_curl {\n  uint curl_mem[];\n};\n\nfloat atomicAdd_curl(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(curl_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_div {\n  uint div_mem[];\n};\n\nfloat atomicAdd_div(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_vy_2 {\n  uint vy_2_mem[];\n};\n\nfloat atomicAdd_vy_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vy_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 3) buffer buf_vx_2 {\n  uint vx_2_mem[];\n};\n\nfloat atomicAdd_vx_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vx_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.M1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.M1) && (index_1 < var.N1);\n  if (is_inside_dispatch)\n  {\n    float vx = asfloat(vx_2_mem[(clamp(index_1 + 1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    float vx_2 = asfloat(vx_2_mem[(clamp(index_1 - 1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    float vy = asfloat(vy_2_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) + clamp(index_0 + 1, 0, var.M1 - 1)]);\n    float vy_2 = asfloat(vy_2_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) + clamp(index_0 - 1, 0, var.M1 - 1)]);\n    float div = (((vx - vx_2) + vy) - vy_2) / 2.0f;\n    div_mem[(index_1 * var.M1) + index_0] = asuint(div);\n    float vy_3 = asfloat(vy_2_mem[(clamp(index_1 + 1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    float vy_4 = asfloat(vy_2_mem[(clamp(index_1 - 1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    float vx_3 = asfloat(vx_2_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) + clamp(index_0 + 1, 0, var.M1 - 1)]);\n    float vx_4 = asfloat(vx_2_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v7_1;\n  int v7_0;\n  int M1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_div_3 {\n  uint div_3_mem[];\n};\n\nfloat atomicAdd_div_3(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_3_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure0 {\n  uint pressure0_mem[];\n};\n\nfloat atomicAdd_pressure0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_div {\n  uint div_mem[];\n};\n\nfloat atomicAdd_div(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v7_1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v7_1) && (index_1 < var.v7_0);\n  if (is_inside_dispatch)\n  {\n    int i = 2 * index_1;\n    int j = 2 * index_0;\n    float div = asfloat(div_mem[(i * var.M1) + j]);\n    float field = (((((i < 3) || (i > 1076)) || (j < 3)) || (j > 1916)) ? 0.0f : 1.0f) * div;\n    int vadd_3 = i + 1;\n    float div_2 = asfloat(div_mem[(vadd_3 * var.M1) + j]);\n    float field_2 = (((((vadd_3 < 3) || (vadd_3 > 1076)) || (j < 3)) || (j > 1916)) ? 0.0f : 1.0f) * div_2;\n    int vadd_6 = j + 1;\n    float div_3 = asfloat(div_mem[(i * var.M1) + vadd_6]);\n    float field_3 = (((((i < 3) || (i > 1076)) || (vadd_6 < 3)) || (vadd_6 > 1916)) ? 0.0f : 1.0f) * div_3;\n    int vadd_9 = i + 1;\n    int vadd_10 = j + 1;\n    float div_4 = asfloat(div_mem[(vadd_9 * var.M1) + vadd_10]);\n    float field_4 = (((((vadd_9 < 3) || (vadd_9 > 1076)) || (vadd_10 < 3)) || (vadd_10 > 1916)) ? 0.0f : 1.0f) * div_4;\n    float res = 0.25f * (((field + field_2) + field_3) + field_4);\n    float pressure0 = 0.0f;\n    pressure0_mem[(index_1 * var.v7_1) + index_0] = asuint(pressure0);\n    float div_5 = 4.0f * res;\n    div_3_mem[(index_1 * var.v7_1) + index_0] = asuint(div_5);\n  }\n}\n'), [('div_3_mem', 'uint'), ('pressure0_mem', 'uint'), ('div_mem', 'uint')])
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v7_1;\n  int v7_0;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure2 {\n  uint pressure2_mem[];\n};\n\nfloat atomicAdd_pressure2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_div_3 {\n  uint div_3_mem[];\n};\n\nfloat atomicAdd_div_3(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_3_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_pressure0 {\n  uint pressure0_mem[];\n};\n\nfloat atomicAdd_pressure0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v7_1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v7_1) && (index_1 < var.v7_0);\n  if (is_inside_dispatch)\n  {\n    float pressure0 = asfloat(pressure0_mem[(index_1 * var.v7_1) + index_0]);\n    int i = index_1 - 1;\n    float pressure = asfloat(pressure0_mem[(clamp(i, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(pressure0_mem[(clamp(i_2, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < 540)) && (index_0 >= 0)) && (index_0 < 960)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < 540)) && (index_0 >= 0)) && (index_0 < 960)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(pressure0_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j, 0, var.v7_1 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(pressure0_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j_2, 0, var.v7_1 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < 540)) && (j >= 0)) && (j < 960)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < 540)) && (j_2 >= 0)) && (j_2 < 960)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_3_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    pressure2_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)] = asuint((((index_1 + index_0) % 2) == 0) ?  ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v7_1;\n  int v7_0;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure0 {\n  uint pressure0_mem[];\n};\n\nfloat atomicAdd_pressure0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure2 {\n  uint pressure2_mem[];\n};\n\nfloat atomicAdd_pressure2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_div_3 {\n  uint div_3_mem[];\n};\n\nfloat atomicAdd_div_3(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_3_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v7_1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v7_1) && (index_1 < var.v7_0);\n  if (is_inside_dispatch)\n  {\n    float pressure2 = asfloat(pressure2_mem[(index_1 * var.v7_1) + index_0]);\n    int i = index_1 - 1;\n    float pressure = asfloat(pressure2_mem[(clamp(i, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(pressure2_mem[(clamp(i_2, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < 540)) && (index_0 >= 0)) && (index_0 < 960)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < 540)) && (index_0 >= 0)) && (index_0 < 960)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(pressure2_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j, 0, var.v7_1 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(pressure2_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j_2, 0, var.v7_1 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < 540)) && (j >= 0)) && (j < 960)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < 540)) && (j_2 >= 0)) && (j_2 < 960)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_3_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    pressure0_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)] = asuint((((index_1 + index_0) % 2) == 1) ?  ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v7_1;\n  int v7_0;\n  int M1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_res1 {\n  uint res1_mem[];\n};\n\nfloat atomicAdd_res1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(res1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_div {\n  uint div_mem[];\n};\n\nfloat atomicAdd_div(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_pressure0 {\n  uint pressure0_mem[];\n};\n\nfloat atomicAdd_pressure0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v7_1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v7_1) && (index_1 < var.v7_0);\n  if (is_inside_dispatch)\n  {\n    float pressure0 = asfloat(pressure0_mem[(index_1 * var.v7_1) + index_0]);\n    int i = 2 * index_1;\n    int j = 2 * index_0;\n    float div = asfloat(div_mem[(i * var.M1) + j]);\n    float field = (((((i < 3) || (i > 1076)) || (j < 3)) || (j > 1916)) ? 0.0f : 1.0f) * div;\n    int vadd_4 = i + 1;\n    float div_2 = asfloat(div_mem[(vadd_4 * var.M1) + j]);\n    float field_2 = (((((vadd_4 < 3) || (vadd_4 > 1076)) || (j < 3)) || (j > 1916)) ? 0.0f : 1.0f) * div_2;\n    int vadd_7 = j + 1;\n    float div_3 = asfloat(div_mem[(i * var.M1) + vadd_7]);\n    float field_3 = (((((i < 3) || (i > 1076)) || (vadd_7 < 3)) || (vadd_7 > 1916)) ? 0.0f : 1.0f) * div_3;\n    int vadd_10 = i + 1;\n    int vadd_11 = j + 1;\n    float div_4 = asfloat(div_mem[(vadd_10 * var.M1) + vadd_11]);\n    float field_4 = (((((vadd_10 < 3) || (vadd_10 > 1076)) || (vadd_11 < 3)) || (vadd_11 > 1916)) ? 0.0f : 1.0f) * div_4;\n    float res = 0.25f * (((field + field_2) + field_3) + field_4);\n    float div_5 = 4.0f * res;\n    float pressure = asfloat(pressure0_mem[(clamp(index_1 - 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    float pressure_2 = asfloat(pressure0_mem[(clamp(index_1 + 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(index_0, 0, var.v7_1 - 1)]);\n    float pressure_3 = asfloat(pressure0_mem[(clamp(index_1, 0, var.v7_0 - 1) * var.v7_1) + cla ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v20_0;\n  int v20_1;\n  int v7_0;\n  int v7_1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure1 {\n  uint pressure1_mem[];\n};\n\nfloat atomicAdd_pressure1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_div_16 {\n  uint div_16_mem[];\n};\n\nfloat atomicAdd_div_16(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_16_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_res1 {\n  uint res1_mem[];\n};\n\nfloat atomicAdd_res1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(res1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v20_0 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v20_0) && (index_1 < var.v20_1);\n  if (is_inside_dispatch)\n  {\n    int i = 2 * index_1;\n    int j = 2 * index_0;\n    float field = asfloat(res1_mem[(clamp(i, 0, var.v7_0 - 1) * var.v7_1) + clamp(j, 0, var.v7_1 - 1)]);\n    float field_2 = asfloat(res1_mem[(clamp(i + 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j, 0, var.v7_1 - 1)]);\n    float field_3 = asfloat(res1_mem[(clamp(i, 0, var.v7_0 - 1) * var.v7_1) + clamp(j + 1, 0, var.v7_1 - 1)]);\n    float field_4 = asfloat(res1_mem[(clamp(i + 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(j + 1, 0, var.v7_1 - 1)]);\n    float res1 = 0.25f * (((field + field_2) + field_3) + field_4);\n    float pressure1 = 0.0f;\n    pressure1_mem[(index_1 * var.v20_0) + index_0] = asuint(pressure1);\n    float div = 4.0f * res1;\n    div_16_mem[(index_1 * var.v20_0) + index_0] = asuint(div);\n  }\n}\n'), [('pressure1_mem', 'uint'), ('div_16_mem', 'uint'), ('res1_mem', 'uint')])
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v20_0;\n  int v20_1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure2_3 {\n  uint pressure2_3_mem[];\n};\n\nfloat atomicAdd_pressure2_3(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_3_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure1 {\n  uint pressure1_mem[];\n};\n\nfloat atomicAdd_pressure1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_div_16 {\n  uint div_16_mem[];\n};\n\nfloat atomicAdd_div_16(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_16_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v20_0 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v20_0) && (index_1 < var.v20_1);\n  if (is_inside_dispatch)\n  {\n    float pressure1 = asfloat(pressure1_mem[(index_1 * var.v20_0) + index_0]);\n    int i = index_1 - 1;\n    float pressure = asfloat(pressure1_mem[(clamp(i, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(pressure1_mem[(clamp(i_2, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < 270)) && (index_0 >= 0)) && (index_0 < 480)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < 270)) && (index_0 >= 0)) && (index_0 < 480)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(pressure1_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(j, 0, var.v20_0 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(pressure1_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(j_2, 0, var.v20_0 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < 270)) && (j >= 0)) && (j < 480)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < 270)) && (j_2 >= 0)) && (j_2 < 480)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_16_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    pressure2_3_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)] = asu ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v20_0;\n  int v20_1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure1 {\n  uint pressure1_mem[];\n};\n\nfloat atomicAdd_pressure1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure2_3 {\n  uint pressure2_3_mem[];\n};\n\nfloat atomicAdd_pressure2_3(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_3_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_div_16 {\n  uint div_16_mem[];\n};\n\nfloat atomicAdd_div_16(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_16_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v20_0 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v20_0) && (index_1 < var.v20_1);\n  if (is_inside_dispatch)\n  {\n    float pressure2 = asfloat(pressure2_3_mem[(index_1 * var.v20_0) + index_0]);\n    int i = index_1 - 1;\n    float pressure = asfloat(pressure2_3_mem[(clamp(i, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(pressure2_3_mem[(clamp(i_2, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < 270)) && (index_0 >= 0)) && (index_0 < 480)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < 270)) && (index_0 >= 0)) && (index_0 < 480)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(pressure2_3_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(j, 0, var.v20_0 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(pressure2_3_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(j_2, 0, var.v20_0 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < 270)) && (j >= 0)) && (j < 480)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < 270)) && (j_2 >= 0)) && (j_2 < 480)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_16_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1)]);\n    pressure1_mem[(clamp(index_1, 0, var.v20_1 - 1) * var.v20_0) + clamp(index_0, 0, var.v20_0 - 1 ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int v7_1;\n  int v7_0;\n  int v20_1;\n  int v20_0;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure0_5 {\n  uint pressure0_5_mem[];\n};\n\nfloat atomicAdd_pressure0_5(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_5_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure1 {\n  uint pressure1_mem[];\n};\n\nfloat atomicAdd_pressure1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_pressure0 {\n  uint pressure0_mem[];\n};\n\nfloat atomicAdd_pressure0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.v7_1 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.v7_1) && (index_1 < var.v7_0);\n  if (is_inside_dispatch)\n  {\n    float pressure0 = asfloat(pressure0_mem[(index_1 * var.v7_1) + index_0]);\n    float x = float(index_1) / 2.0f;\n    float y = float(index_0) / 2.0f;\n    float xi = floor(x);\n    float yi = floor(y);\n    float xf = x - xi;\n    float yf = y - yi;\n    int xi_2 = int(xi);\n    int yi_2 = int(yi);\n    float oxf = 1.0f - xf;\n    float oyf = 1.0f - yf;\n    float tex = asfloat(pressure1_mem[(clamp(xi_2, 0, var.v20_1 - 1) * var.v20_0) + clamp(yi_2, 0, var.v20_0 - 1)]);\n    float tex_2 = asfloat(pressure1_mem[(clamp(xi_2 + 1, 0, var.v20_1 - 1) * var.v20_0) + clamp(yi_2, 0, var.v20_0 - 1)]);\n    float tex_3 = asfloat(pressure1_mem[(clamp(xi_2, 0, var.v20_1 - 1) * var.v20_0) + clamp(yi_2 + 1, 0, var.v20_0 - 1)]);\n    float tex_4 = asfloat(pressure1_mem[(clamp(xi_2 + 1, 0, var.v20_1 - 1) * var.v20_0) + clamp(yi_2 + 1, 0, var.v20_0 - 1)]);\n    float pressure0_2 = pressure0 + (((((tex * oxf) * oyf) + ((tex_2 * xf) * oyf)) + ((tex_3 * oxf) * yf)) + ((tex_4 * xf) * yf));\n    pressure0_5_mem[(index_1 * var.v7_1) + index_0] = asuint(pressure0_2);\n  }\n}\n'), [('pressure0_5_mem', 'uint'), ('pressure1_mem', 'uint'), ('pressure0_mem', 'uint')])
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1_3;\n  int N1_3;\n  int v7_0;\n  int v7_1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure_22 {\n  uint pressure_22_mem[];\n};\n\nfloat atomicAdd_pressure_22(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure_22_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_m0 {\n  uint m0_mem[];\n};\n\nfloat atomicAdd_m0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(m0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_pressure0_5 {\n  uint pressure0_5_mem[];\n};\n\nfloat atomicAdd_pressure0_5(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure0_5_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.M1_3 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.M1_3) && (index_1 < var.N1_3);\n  if (is_inside_dispatch)\n  {\n    float x = float(index_1) / 2.0f;\n    float y = float(index_0) / 2.0f;\n    float xi = floor(x);\n    float yi = floor(y);\n    float xf = x - xi;\n    float yf = y - yi;\n    int xi_2 = int(xi);\n    int yi_2 = int(yi);\n    float oxf = 1.0f - xf;\n    float oyf = 1.0f - yf;\n    float tex = asfloat(pressure0_5_mem[(clamp(xi_2, 0, var.v7_0 - 1) * var.v7_1) + clamp(yi_2, 0, var.v7_1 - 1)]);\n    float tex_2 = asfloat(pressure0_5_mem[(clamp(xi_2 + 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(yi_2, 0, var.v7_1 - 1)]);\n    float tex_3 = asfloat(pressure0_5_mem[(clamp(xi_2, 0, var.v7_0 - 1) * var.v7_1) + clamp(yi_2 + 1, 0, var.v7_1 - 1)]);\n    float tex_4 = asfloat(pressure0_5_mem[(clamp(xi_2 + 1, 0, var.v7_0 - 1) * var.v7_1) + clamp(yi_2 + 1, 0, var.v7_1 - 1)]);\n    float vadd_12 = ((((tex * oxf) * oyf) + ((tex_2 * xf) * oyf)) + ((tex_3 * oxf) * yf)) + ((tex_4 * xf) * yf);\n    m0_mem[(index_1 * var.M1_3) + index_0] = asuint(vadd_12);\n    pressure_22_mem[(index_1 * var.M1_3) + index_0] = asuint(vadd_12);\n  }\n}\n'), [('pressure_22_mem', 'uint'), ('m0_mem', 'uint'), ('pressure0_5_mem', 'uint')])
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1_3;\n  int N1_3;\n  int N1;\n  int M1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_pressure2_5 {\n  uint pressure2_5_mem[];\n};\n\nfloat atomicAdd_pressure2_5(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_5_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_div {\n  uint div_mem[];\n};\n\nfloat atomicAdd_div(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_m0 {\n  uint m0_mem[];\n};\n\nfloat atomicAdd_m0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(m0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.M1_3 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.M1_3) && (index_1 < var.N1_3);\n  if (is_inside_dispatch)\n  {\n    float vload = asfloat(m0_mem[(index_1 * var.M1_3) + index_0]);\n    int M1 = 1920;\n    int N1 = 1080;\n    int i = index_1 - 1;\n    float pressure = asfloat(m0_mem[(clamp(i, 0, var.N1_3 - 1) * var.M1_3) + clamp(index_0, 0, var.M1_3 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(m0_mem[(clamp(i_2, 0, var.N1_3 - 1) * var.M1_3) + clamp(index_0, 0, var.M1_3 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < N1)) && (index_0 >= 0)) && (index_0 < M1)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < N1)) && (index_0 >= 0)) && (index_0 < M1)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(m0_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(j, 0, var.M1_3 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(m0_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(j_2, 0, var.M1_3 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < N1)) && (j >= 0)) && (j < M1)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < N1)) && (j_2 >= 0)) && (j_2 < M1)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    pressure2_5_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(index_0, 0, var.M1_3 - 1)] = asuint((((index_1 + index_0) % 2) == 0) ? mix(vload, (vadd_10 ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1_3;\n  int N1_3;\n  int N1;\n  int M1;\n};\n\n', 'layout(std430, binding = 0) buffer buf_m0 {\n  uint m0_mem[];\n};\n\nfloat atomicAdd_m0(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(m0_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_pressure2_5 {\n  uint pressure2_5_mem[];\n};\n\nfloat atomicAdd_pressure2_5(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(pressure2_5_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_div {\n  uint div_mem[];\n};\n\nfloat atomicAdd_div(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(div_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\n\nlayout(std140) uniform UBOBlock {\n  UBO var;\n};\n\n', 'layout (local_size_x = 16, local_size_y = 16, local_size_z = 1) in;\n\nvoid main() {\n  int block_id = int(gl_WorkGroupID.x);\n  int block_thread_id0 = int(gl_LocalInvocationID.x);\n  int block_thread_id1 = int(gl_LocalInvocationID.y);\n  int block_thread_id2 = int(gl_LocalInvocationID.z);\n\n  int blocks_shape_0 = ((var.M1_3 + 16) - 1) / 16;\n  int vdiv = block_id / blocks_shape_0;\n  int index_0 = ((block_id - (vdiv * blocks_shape_0)) * 16) + block_thread_id0;\n  int index_1 = (vdiv * 16) + block_thread_id1;\n  bool is_inside_dispatch = (index_0 < var.M1_3) && (index_1 < var.N1_3);\n  if (is_inside_dispatch)\n  {\n    float pressure2 = asfloat(pressure2_5_mem[(index_1 * var.M1_3) + index_0]);\n    int M1 = 1920;\n    int N1 = 1080;\n    int M1_2 = 1920;\n    int N1_2 = 1080;\n    int i = index_1 - 1;\n    float pressure = asfloat(pressure2_5_mem[(clamp(i, 0, var.N1_3 - 1) * var.M1_3) + clamp(index_0, 0, var.M1_3 - 1)]);\n    int i_2 = index_1 + 1;\n    float pressure_2 = asfloat(pressure2_5_mem[(clamp(i_2, 0, var.N1_3 - 1) * var.M1_3) + clamp(index_0, 0, var.M1_3 - 1)]);\n    float vadd_6 = (((((i >= 0) && (i < N1_2)) && (index_0 >= 0)) && (index_0 < M1_2)) ? pressure : 0.0f) + (((((i_2 >= 0) && (i_2 < N1)) && (index_0 >= 0)) && (index_0 < M1)) ? pressure_2 : 0.0f);\n    int j = index_0 - 1;\n    float pressure_3 = asfloat(pressure2_5_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(j, 0, var.M1_3 - 1)]);\n    int j_2 = index_0 + 1;\n    float pressure_4 = asfloat(pressure2_5_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(j_2, 0, var.M1_3 - 1)]);\n    float vadd_10 = (vadd_6 + (((((index_1 >= 0) && (index_1 < N1)) && (j >= 0)) && (j < M1)) ? pressure_3 : 0.0f)) + (((((index_1 >= 0) && (index_1 < N1)) && (j_2 >= 0)) && (j_2 < M1)) ? pressure_4 : 0.0f);\n    float div = asfloat(div_mem[(clamp(index_1, 0, var.N1 - 1) * var.M1) + clamp(index_0, 0, var.M1 - 1)]);\n    m0_mem[(clamp(index_1, 0, var.N1_3 - 1) * var.M1_3) + clamp(in ...
# (('\n#version 460\n\nuint pcg(uint v) {\n  uint state = v * 747796405u + 2891336453u;\n  uint word = ((state >> ((state >> 28u) + 4u)) ^ state) * 277803737u;\n  return (word >> 22u) ^ word;\n}\n\nfloat pcgf(uint v) {\n  return float(pcg(v)) / float(0xffffffffu);\n}\n\nfloat asfloat(uint x) {\n  return uintBitsToFloat(x);\n}\n\nuint asuint(float x) {\n  return floatBitsToUint(x);\n}\n\nuint asuint(bool x) {\n\treturn uint(x);\n}\n\nuint asuint(int x) {\n  return uint(x);\n}\n\nuint asuint(uint x) {\n  return x;\n}\n\nint asint(uint x) {\n  return int(x);\n}\n\nbool asbool(uint x) {\n  return bool(x);\n}\n\n\nstruct UBO {\n  int M1;\n  int N1;\n  int M1_3;\n  int v1_1;\n  int N1_3;\n  int v1_2;\n  int v1_3;\n  int v1_4;\n};\n\n', 'layout(std430, binding = 0) buffer buf_canvas {\n  uint canvas_mem[];\n};\n\nfloat atomicAdd_canvas(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(canvas_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 1) buffer buf_m1 {\n  uint m1_mem[];\n};\n\nfloat atomicAdd_m1(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(m1_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 2) buffer buf_vx_11 {\n  uint vx_11_mem[];\n};\n\nfloat atomicAdd_vx_11(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vx_11_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 3) buffer buf_vy_11 {\n  uint vy_11_mem[];\n};\n\nfloat atomicAdd_vy_11(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vy_11_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 4) buffer buf_params {\n  uint params_mem[];\n};\n\nfloat atomicAdd_params(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(params_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 5) buffer buf_vy_2 {\n  uint vy_2_mem[];\n};\n\nfloat atomicAdd_vy_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vy_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 6) buffer buf_vx_2 {\n  uint vx_2_mem[];\n};\n\nfloat atomicAdd_vx_2(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(vx_2_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttmp1 = tmp0;\n\t\tuval = floatBitsToUint(val + uintBitsToFloat(tmp1));\n\t}\n\n\treturn uintBitsToFloat(tmp1);\n}\n\nlayout(std430, binding = 7) buffer buf_curl {\n  uint curl_mem[];\n};\n\nfloat atomicAdd_curl(int index, float val) {\n\tuint uval = floatBitsToUint(val);\n\tuint tmp0 = 0;\n\tuint tmp1 = 0;\n\n\twhile (true) {\n\t\ttmp0 = atomicCompSwap(curl_mem[index], tmp1, uval);\n\t\tif (tmp1 == tmp0) break;\n\t\ttm ...

# %%
M = 1920
N = 1080 

VX = tf.tensor(np.zeros((N, M)))
VY = tf.tensor(np.zeros((N, M)))
PRESSURE = tf.tensor(np.zeros((N, M)))
DENSITY = tf.tensor(np.zeros((N, M)))

tf.window.show(M, N, "Fluid simulation")

pmx, pmy = tf.window.get_mouse_position()

mouse = np.zeros(5)

time_step = 1.0
vorticity_scale = 0.0
vel_render_scale = 1.0
den_render_scale = 0.0
velocity_decay = 0.999
density_decay = 0.999

while not tf.window.should_close():
    mx, my = tf.window.get_mouse_position()

    cur_time = time.time()
    mouse[0] = mx
    mouse[1] = N - my

    if tf.window.is_mouse_button_pressed(tf.window.MOUSE_BUTTON_0):
        mouse[2] = 0.1*(pmy - my)
        mouse[3] = 0.1*(mx - pmx)
        mouse[4] = 1.0
    else:
        mouse[2] = 0.0
        mouse[3] = 0.0
        mouse[4] = 0.0
    
    MOUSE = tf.tensor(mouse)

    params = np.array([time_step, vorticity_scale, vel_render_scale, den_render_scale, velocity_decay, density_decay])
    PARAMS = tf.tensor(params)

    IPF = 10

    for i in range(IPF):
        VX, VY, PRESSURE, CANVAS, DIV, DENSITY, RES = fluid(VX, VY, PRESSURE, DENSITY, MOUSE, PARAMS)

    tf.window.render_frame(CANVAS)
    frame_time = time.time() - cur_time

    tf.imgui.begin("Fluid simulation")
    time_step = tf.imgui.slider("Time step", time_step, 0.0, 10.0)
    vorticity_scale = tf.imgui.slider("Vorticity scale", vorticity_scale, 0.0, 0.1)
    vel_render_scale = tf.imgui.slider("Velocity render scale", vel_render_scale, 0.0, 10.0)
    den_render_scale = tf.imgui.slider("Density render scale", den_render_scale, 0.0, 10.0)
    velocity_decay = tf.imgui.slider("Velocity decay", velocity_decay, 0.99, 1.0)
    density_decay = tf.imgui.slider("Density decay", density_decay, 0.99, 1.0)
    tf.imgui.text("Frame time: %f" % frame_time)
    tf.imgui.text("FPS: %f" % (1.0/frame_time))
    tf.imgui.text("Iterations per second: %f" % (IPF/frame_time))
    tf.imgui.end()


    pmx, pmy = mx, my

# %%
#do a few steps and measure performance by timing every 100 steps
#start = time.time()
#
##file_path = 'H:/TestVideos/fluid.gif'
##writer = imageio.get_writer(file_path, fps=30, loop=0)
#
##use opencv to write is as video too
#video_path = 'H:/TestVideos/fluid.mp4'
#fourcc = cv.VideoWriter_fourcc(*'H264')
#video = cv.VideoWriter(video_path, fourcc, 60, (M, N))
#
#for i in range(5000):
#    VX, VY, PRESSURE, CANVAS, DIV, DENSITY, RES = fluid(VX, VY, PRESSURE, DENSITY)
#
#    if i % 10 == 0:
#        color = CANVAS.numpy
#        color_rgb = color.astype(np.uint8)
#        #writer.append_data(color_rgb)
#        video.write(cv.cvtColor(color_rgb, cv.COLOR_BGR2RGB))
#
#    if i % 250 == 249:
#        print("Iteration: " + str(i+1) + ", IPS: " + str(250.0/(time.time()-start)))
#        start = time.time()
#
#print("Used memory: " + str(tf.used_memory()*4.0/1024.0/1024.0) + " MB")
#
##writer.close()
#video.release()

# %%
# plot color_rgb
color = CANVAS.numpy
plt.figure(figsize=(10,5))
plt.imshow(color)
plt.colorbar()
plt.show()

# %%
# plot the final velocity with colorbar
plt.figure(figsize=(10,5))
plt.imshow(np.sqrt(VX.numpy**2.0 + VY.numpy**2.0))
plt.colorbar()
plt.title('Velocity')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# plot the final pressure with colorbar
plt.figure(figsize=(10,5))
plt.imshow(PRESSURE.numpy)
plt.colorbar()
plt.title('Pressure')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# plot the final divergence with colorbar
plt.figure(figsize=(10,5))
plt.imshow(DIV.numpy)
plt.colorbar()
plt.title('Divergence')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# plot the abs residual with colorbar in log scale
plt.figure(figsize=(10,5))
plt.imshow(np.log10(np.abs(RES.numpy)+1e-8), cmap='gist_rainbow')
plt.colorbar()
plt.title('Residual')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
